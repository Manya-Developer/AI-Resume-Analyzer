# %%
import sys

print(sys.executable)
print(sys.version)
# Out:
# d:\anaconda\envs\resume-ai\python.exe
# 3.11.15 | packaged by Anaconda, Inc. | (main, Jun 11 2026, 15:12:53) [MSC v.1942 64 bit (AMD64)]

# %%
resume = """
Python Machine Learning Pandas NumPy SQL Git
"""

job_description = """
Looking for a Machine Learning Intern with experience
in Python, Pandas, SQL, Scikit-learn and Git.
"""

print("RESUME:")
print(resume)

print("\nJOB DESCRIPTION:")
print(job_description)
# Out:
# RESUME:
#
# Python Machine Learning Pandas NumPy SQL Git
#
#
# JOB DESCRIPTION:
#
# Looking for a Machine Learning Intern with experience
# in Python, Pandas, SQL, Scikit-learn and Git.

# %%
print(type(resume))
print(type(job_description))
# Out:
# <class 'str'>
# <class 'str'>

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer

print("Everything is working!")
# Out:
# Everything is working!

# %%
documents = [resume, job_description]

vectorizer = TfidfVectorizer()

tfidf_matrix = vectorizer.fit_transform(documents)

# %%
print(tfidf_matrix)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 22 stored elements and shape (2, 16)>
#   Coords	Values
#   (0, 12)	0.3540997415957358
#   (0, 9)	0.3540997415957358
#   (0, 7)	0.3540997415957358
#   (0, 11)	0.3540997415957358
#   (0, 10)	0.4976748316029239
#   (0, 14)	0.3540997415957358
#   (0, 3)	0.3540997415957358
#   (1, 12)	0.2050748649614315
#   (1, 9)	0.2050748649614315
#   (1, 7)	0.2050748649614315
#   (1, 11)	0.2050748649614315
#   (1, 14)	0.2050748649614315
#   (1, 3)	0.2050748649614315
#   (1, 8)	0.2882255672532856
#   (1, 2)	0.2882255672532856
#   (1, 5)	0.2882255672532856
#   (1, 15)	0.2882255672532856
#   (1, 1)	0.2882255672532856
#   (1, 4)	0.2882255672532856
#   (1, 13)	0.2882255672532856
#   (1, 6)	0.2882255672532856
#   (1, 0)	0.2882255672532856

# %%
print(vectorizer.get_feature_names_out())
# Out:
# ['and' 'experience' 'for' 'git' 'in' 'intern' 'learn' 'learning' 'looking'
#  'machine' 'numpy' 'pandas' 'python' 'scikit' 'sql' 'with']

# %%
import pandas as pd

tfidf_df = pd.DataFrame(
    tfidf_matrix.toarray(),
    columns=vectorizer.get_feature_names_out()
)

print(tfidf_df)
# Out:
#         and  experience       for       git        in    intern     learn  \
# 0  0.000000    0.000000  0.000000  0.354100  0.000000  0.000000  0.000000
# 1  0.288226    0.288226  0.288226  0.205075  0.288226  0.288226  0.288226
#
#    learning   looking   machine     numpy    pandas    python    scikit  \
# 0  0.354100  0.000000  0.354100  0.497675  0.354100  0.354100  0.000000
# 1  0.205075  0.288226  0.205075  0.000000  0.205075  0.205075  0.288226
#
#         sql      with
# 0  0.354100  0.000000
# 1  0.205075  0.288226

# %%
from sklearn.metrics.pairwise import cosine_similarity

similarity = cosine_similarity(tfidf_matrix[0:1], tfidf_matrix[1:2])

print(similarity)
# Out:
# [[0.43570174]]

# %%
match_score = similarity[0][0] * 100

print(f"Resume Match Score: {match_score:.2f}%")
# Out:
# Resume Match Score: 43.57%
